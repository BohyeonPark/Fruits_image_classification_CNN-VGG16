# %% [markdown]
# <numpy 응용 - 미세먼지 데이터 시각화>
# - Pandas의 DataFrame 객체를 사용하여 프로그램을 작성하자
# - Numpy를 이용하여 DataFrame 연산을 처리하자
# - Matplotlib 라이브러리
# - plt.bar() 이용
# - plt.subplot() 이용

# %% [markdown]
# 미세먼지 상태를 시간에 따라 어떻게 변하는지 알아보자
# - 미세먼지와 초미세먼지 정보를 기상청으로부터 가져와서 막대 그래프로 보여준다.
# - 미세먼지와 초미세먼지 농도에 따라 다른 색깔의 막대 그래프로 나타낸다.
# - 입력: 미세먼지 데이터를 초기 값으로 제공
# - 출력: 초미세먼지 막대그래프, 미세먼지 막대그래프
# - 고려사항
#   - 어떤 색상을 사용할 것인가?
#   - 가로, 세로축은 어떻게 표시할 것인가?
#   - 초미세먼지를 나타내기 위한 정수 배열과 1-10시까지 시간을 나타내기 위한 문자열 리스트

# %%
# 미세먼지 데이터 시각화 

# hour : 1시 ~ 10시 문자열 리스트
# pm25 : 시간에 따른 초미세먼지 정수형 배열
# pm10 : 시간에 따른 미세먼지 정수형 배열

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

hour=['1h','2h','3h','4h','5h','6h','7h','8h','9h','10h']
pm25=np.array([34,37,30,27,35,38,43,42,37,14])
pm10=np.array([46,49,41,40,81,90,53,52,55,51])

plt.figure(figsize=(10,10))
plt.subplot(2,1,1)

for i in range(10):
  if pm25[i]<15:
    plt.bar(hour[i],pm25[i],color='blue')
  elif 15<=pm25[i]<35:
    plt.bar(hour[i],pm25[i],color='green')
  elif 35 <=pm25[i]<75:
    plt.bar(hour[i],pm25[i],color='orange')
  elif pm25[i]>=75:
    plt.bar(hour[i],pm25[i],color='red')
plt.title('pm2.5')

plt.subplot(2,1,2)
for i in range(10):
  if pm10[i]<30:
    plt.bar(hour[i],pm10[i],color='blue')
  elif 30<=pm10[i]<80:
    plt.bar(hour[i],pm10[i],color='green')
  elif 80<=pm10[i]<150:
    plt.bar(hour[i],pm10[i],color='orange')
  elif pm10[i]>=150:
    plt.bar(hour[i],pm10[i],color='red')
plt.title('pm10')
plt.show()

# %%
# random 모듈

import random
import matplotlib.pyplot as plt

incircle=0

simcount=int(input('최대 몇번 시뮬레이션을 할까요?'))

circle_center=(0,0)
circle_radius=1

c=plt.Circle(circle_center,circle_radius, ec='b',fill=False)

a=plt.axes(xlim=(-1,1),ylim=(-1,1))
a.add_patch(c) #a에 c patch
a.set_aspect('equal') #set_aspect() x축과 y축 비율을 동일하게 설정

for i in range(simcount):
  x=random.uniform(-1.0, 1.0)
  y=random.uniform(-1.0, 1.0)
  plt.scatter(x,y,s=2)

  dot_value=x*x+y*y #x,y축 크기 확장
  if dot_value<=1:
    incircle = incircle+1

print('Pi=',4*incircle/simcount)
plt.show()
# Out:
# 최대 몇번 시뮬레이션을 할까요?10
# Pi= 3.2

# %%
# random 모듈

import random
import matplotlib.pyplot as plt

incircle=0

simcount=int(input('최대 몇번 시뮬레이션을 할까요?'))

circle_center=(0,0)
circle_radius=1

c=plt.Circle(circle_center,circle_radius, ec='b',fill=False)

a=plt.axes(xlim=(-1,1),ylim=(-1,1))
a.add_patch(c) #a에 c patch
a.set_aspect('equal') #set_aspect() x축과 y축 비율을 동일하게 설정

for i in range(simcount):
  x=random.uniform(-1.0, 1.0)
  y=random.uniform(-1.0, 1.0)
  plt.scatter(x,y,s=2)

  dot_value=x*x+y*y #x,y축 크기 확장
  if dot_value<=1:
    incircle = incircle+1

print('Pi=',4*incircle/simcount)
plt.show()
# Out:
# 최대 몇번 시뮬레이션을 할까요?100
# Pi= 3.56

# %%
# random 모듈

import random
import matplotlib.pyplot as plt

incircle=0

simcount=int(input('최대 몇번 시뮬레이션을 할까요?'))

circle_center=(0,0)
circle_radius=1

c=plt.Circle(circle_center,circle_radius, ec='b',fill=False)

a=plt.axes(xlim=(-1,1),ylim=(-1,1))
a.add_patch(c) #a에 c patch
a.set_aspect('equal') #set_aspect() x축과 y축 비율을 동일하게 설정

for i in range(simcount):
  x=random.uniform(-1.0, 1.0)
  y=random.uniform(-1.0, 1.0)
  plt.scatter(x,y,s=2)

  dot_value=x*x+y*y #x,y축 크기 확장
  if dot_value<=1:
    incircle = incircle+1

print('Pi=',4*incircle/simcount)
plt.show()
# Out:
# 최대 몇번 시뮬레이션을 할까요?1000
# Pi= 3.164

# %%
# random 모듈

import random
import matplotlib.pyplot as plt

incircle=0

simcount=int(input('최대 몇번 시뮬레이션을 할까요?'))

circle_center=(0,0)
circle_radius=1

c=plt.Circle(circle_center,circle_radius, ec='b',fill=False)

a=plt.axes(xlim=(-1,1),ylim=(-1,1))
a.add_patch(c) #a에 c patch
a.set_aspect('equal') #set_aspect() x축과 y축 비율을 동일하게 설정

for i in range(simcount):
  x=random.uniform(-1.0, 1.0)
  y=random.uniform(-1.0, 1.0)
  plt.scatter(x,y,s=2)

  dot_value=x*x+y*y #x,y축 크기 확장
  if dot_value<=1:
    incircle = incircle+1

print('Pi=',4*incircle/simcount)
plt.show()
# Out:
# 최대 몇번 시뮬레이션을 할까요?10000
# Pi= 3.1428

# %%
#시뮬레이션을 많이 돌릴 수록 원주율 3.14에 가까워짐

# %% [markdown]
# <가위바위보 게임>
# - 항목 앞의 키에는 승자, 값에는 패자의 손 모양을 기술
# - 결과 화면
# ![1.png](data:image/png;base64,...)

# %%
from random import choice

medewin={'가위':'보','바위':'가위','보':'바위'}

game=['가위#바위#보 게임 시작','가위','바위','보']
msg=['비겼습니다','축하합니다!','당신이 이겼습니다']
msg.append('아쉽지만, 컴퓨터가 이겼습니다')

print((game[0]+'시작').center(55,'='))

while True:
  try: #예외처리
    s='0(종료), 1(가위), 2(바위). 3(보[자기]) 중 하나 선택 >>'
    num=int(input(s))
  except:
    num=1 #예외처리 일 경우, 무조건 1 가위로 설정하겠다
  if num==0:
    break
  if not(0<=num<=3):
    print('입력이 잘못되었습니다. 다시 입력하세요')
    continue
  
  player=game[num]
  com=choice(game[1:])

  if player == com:
    winner=0
  elif medewin[player] == com:
    winner=1 #당신이 승리
  else:
    winner=2 #컴퓨터 승리

  print('당신',player,'vs','컴퓨터',com)
  print(msg[winner]+'\n')

print('\n','종료합니다'.center(60,'='))
# Out:
# ====================가위#바위#보 게임 시작시작====================
# 0(종료), 1(가위), 2(바위). 3(보[자기]) 중 하나 선택 >>3
# 당신 보 vs 컴퓨터 가위
# 당신이 이겼습니다
#
# 0(종료), 1(가위), 2(바위). 3(보[자기]) 중 하나 선택 >>2
# 당신 바위 vs 컴퓨터 바위
# 비겼습니다
#
# 0(종료), 1(가위), 2(바위). 3(보[자기]) 중 하나 선택 >>2
# 당신 바위 vs 컴퓨터 보
# 당신이 이겼습니다
#
# 0(종료), 1(가위), 2(바위). 3(보[자기]) 중 하나 선택 >>1
# 당신 가위 vs 컴퓨터 가위
# 비겼습니다
#
# 0(종료), 1(가위), 2(바위). 3(보[자기]) 중 하나 선택 >>0
#
#  ===========================종료합니다============================
